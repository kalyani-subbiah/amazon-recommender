# %% [markdown]
# # Data Split

# %% [markdown]
# ## 0 Global Settings

# %%
import sys

import pyspark
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

from pyspark.sql.functions import col

from recommenders.utils.spark_utils import start_or_get_spark
from recommenders.datasets.download_utils import maybe_download
from recommenders.datasets.spark_splitters import (
    spark_random_split, 
    spark_chrono_split, 
    spark_stratified_split
)
from recommenders.datasets.spark_splitters import spark_random_split

print("System version: {}".format(sys.version))
print("Pyspark version: {}".format(pyspark.__version__))
# Out:
# System version: 3.9.12 (main, May  8 2022, 14:00:45)
# [Clang 10.0.1 (clang-1001.0.46.4)]
# Pyspark version: 3.2.1

# %% [markdown]
# ## 1 Data Preparation

# %% [markdown]
# ### 1.1 Data Understanding

# %%
DATA_PATH='../data/amazon_reviews_us_Electronics_v1_00.tsv'

COL_USER = "customer_id"
COL_ITEM = "product_id"
COL_RATING = "star_rating"
COL_PREDICTION = "star_rating"
COL_TIMESTAMP = "review_date"

# %%
spark = pyspark.sql.SparkSession.builder.getOrCreate()
data = spark.read.option("delimiter", "\t").option("header", True).csv(DATA_PATH)

# %%
display(data.show(2))
# Out:
# +-----------+-----------+--------------+----------+--------------+--------------------+----------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# |marketplace|customer_id|     review_id|product_id|product_parent|       product_title|product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|     review_headline|         review_body|review_date|
# +-----------+-----------+--------------+----------+--------------+--------------------+----------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# |         US|   41409413|R2MTG1GCZLR2DK|B00428R89M|     112201306|yoomall 5M Antenn...|     Electronics|          5|            0|          0|   N|                Y|          Five Stars|       As described.| 2015-08-31|
# |         US|   49668221|R2HBOEM8LE9928|B000068O48|     734576678|Hosa GPM-103 3.5m...|     Electronics|          5|            0|          0|   N|                Y|It works as adver...|It works as adver...| 2015-08-31|
# +-----------+-----------+--------------+----------+--------------+--------------------+----------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# only showing top 2 rows
# None

# %%
data.describe()
# Out:
# DataFrame[summary: string, marketplace: string, customer_id: string, review_id: string, product_id: string, product_parent: string, product_title: string, product_category: string, star_rating: string, helpful_votes: string, total_votes: string, vine: string, verified_purchase: string, review_headline: string, review_body: string, review_date: string]

# %%
print(
    "Total number of ratings are\t{}".format(data.count()),
    "Total number of users are\t{}".format(data.select(col(COL_USER)).distinct().count()),
    "Total number of items are\t{}".format(data.select(col(COL_ITEM)).distinct().count()),
    sep="\n"
)
# Out:
# [Stage 45:===================================>                     (8 + 5) / 13]
# Total number of ratings are	3093869
# Total number of users are	2154357
# Total number of items are	185852

# %% [markdown]
# ### 1.2 Data transformation

# %% [markdown]
# Convert original timestamps to ISO format

# %%
from pyspark.sql.functions import to_date

data.withColumn("datetype", to_date(col(COL_TIMESTAMP), "yyyy-MM-dd")).show(2)
# Out:
# +-----------+-----------+--------------+----------+--------------+--------------------+----------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+----------+
# |marketplace|customer_id|     review_id|product_id|product_parent|       product_title|product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|     review_headline|         review_body|review_date|  datetype|
# +-----------+-----------+--------------+----------+--------------+--------------------+----------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+----------+
# |         US|   41409413|R2MTG1GCZLR2DK|B00428R89M|     112201306|yoomall 5M Antenn...|     Electronics|          5|            0|          0|   N|                Y|          Five Stars|       As described.| 2015-08-31|2015-08-31|
# |         US|   49668221|R2HBOEM8LE9928|B000068O48|     734576678|Hosa GPM-103 3.5m...|     Electronics|          5|            0|          0|   N|                Y|It works as adver...|It works as adver...| 2015-08-31|2015-08-31|
# +-----------+-----------+--------------+----------+--------------+--------------------+----------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+----------+
# only showing top 2 rows

# %% [markdown]
# ## 2 Experimentation Protocol

# %% [markdown]
# Experimentation protocol is usually set up to favor a reasonable evaluation for a specific recommendation scenario. For example,
#
# Recommender-A is to recommend movies to people by taking people's collaborative rating similarities. To make sure the evaluation is statisically sound, the same set of users for both model building and testing should be used (to avoid any cold-ness of users), and a stratified splitting strategy should be taken.
# Recommender-B is to recommend fashion products to customers. It makes sense that evaluation of the recommender considers time-dependency of customer purchases, as apparently, tastes of the customers in fashion items may be drifting over time. In this case, a chronologically splitting should be used.

# %% [markdown]
# ## 3 Data split
#
# ### 3.1 Random split
#
# Random split simply takes in a data set and outputs the splits of the data, given the split ratios.

# %%
type(data)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
data_train, data_test = spark_random_split(data, ratio=0.7)

# %%
data_train.count(), data_test.count()
# Out:
# (2166025, 927844)

# %% [markdown]
# Multi-split:

# %%
data_train, data_validate, data_test = spark_random_split(data, ratio=[0.6, 0.2, 0.2])
# or
data_train, data_validate, data_test = spark_random_split(data, ratio=[3, 1, 1])

# %%
data_train.shape[0], data_validate.shape[0], data_test.shape[0]

# %% [markdown]
# ### 3.2 Chronological Split
#
# #### 3.2.1 "Filter by"
#
# Chrono splitting can be either by "user" or "item". For example, if it is by "user" and the splitting ratio is 0.7, it means that first 70% ratings for each user in the data will be put into one split while the other 30% is in another. It is worth noting that a chronological split is not "random" because splitting is timestamp-dependent.

# %%
data_train, data_test = spark_chrono_split(
    data, ratio=0.7, filter_by="user",
    col_user=COL_USER, col_item=COL_ITEM, col_timestamp=COL_TIMESTAMP
)
# Out:
# 22/05/15 10:14:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:10 WARN BlockManager: Block rdd_24_6 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:10 WARN BlockManager: Block rdd_24_5 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:10 WARN BlockManager: Block rdd_24_1 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:10 WARN BlockManager: Block rdd_24_7 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:10 WARN BlockManager: Block rdd_24_3 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:10 WARN BlockManager: Block rdd_24_4 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:10 WARN BlockManager: Block rdd_24_2 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:10 WARN BlockManager: Block rdd_24_0 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:13 WARN BlockManager: Block rdd_24_13 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:13 WARN BlockManager: Block rdd_24_10 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:13 WARN BlockManager: Block rdd_24_14 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:13 WARN BlockManager: Block rdd_24_12 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:13 WARN BlockManager: Block rdd_24_11 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:13 WARN BlockManager: Block rdd_24_15 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:13 WARN BlockManager: Block rdd_24_9 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:13 WARN BlockManager: Block rdd_24_8 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:14 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:14 WARN BlockManager: Block rdd_24_16 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:17 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:17 WARN BlockManager: Block rdd_24_17 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:17 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:17 WARN BlockManager: Block rdd_24_18 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:17 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:17 WARN BlockManager: Block rdd_24_19 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:17 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:17 WARN BlockManager: Block rdd_24_21 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:17 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:17 WARN BlockManager: Block rdd_24_24 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:17 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:17 WARN BlockManager: Block rdd_24_22 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:17 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:17 WARN BlockManager: Block rdd_24_23 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:17 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:17 WARN BlockManager: Block rdd_24_20 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:19 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:19 WARN BlockManager: Block rdd_24_25 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:19 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:19 WARN BlockManager: Block rdd_24_30 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:19 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:19 WARN BlockManager: Block rdd_24_31 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:19 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:19 WARN BlockManager: Block rdd_24_27 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:19 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:19 WARN BlockManager: Block rdd_24_29 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:19 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:19 WARN BlockManager: Block rdd_24_32 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:19 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:19 WARN BlockManager: Block rdd_24_26 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:19 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:19 WARN BlockManager: Block rdd_24_28 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:20 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:20 WARN BlockManager: Block rdd_24_34 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:20 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:20 WARN BlockManager: Block rdd_24_35 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:20 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:20 WARN BlockManager: Block rdd_24_33 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:20 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:20 WARN BlockManager: Block rdd_24_39 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:20 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:20 WARN BlockManager: Block rdd_24_40 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:21 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:21 WARN BlockManager: Block rdd_24_36 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:21 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:21 WARN BlockManager: Block rdd_24_38 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:21 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:21 WARN BlockManager: Block rdd_24_37 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:21 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:21 WARN BlockManager: Block rdd_24_41 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:21 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:21 WARN BlockManager: Block rdd_24_42 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:22 WARN BlockManager: Block rdd_24_43 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:22 WARN BlockManager: Block rdd_24_44 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:22 WARN BlockManager: Block rdd_24_45 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:22 WARN BlockManager: Block rdd_24_47 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:22 WARN BlockManager: Block rdd_24_46 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:22 WARN BlockManager: Block rdd_24_48 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:22 WARN BlockManager: Block rdd_24_49 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:22 WARN BlockManager: Block rdd_24_50 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:22 WARN BlockManager: Block rdd_24_51 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:22 WARN BlockManager: Block rdd_24_52 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:23 WARN BlockManager: Block rdd_24_53 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:23 WARN BlockManager: Block rdd_24_54 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:23 WARN BlockManager: Block rdd_24_56 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:23 WARN BlockManager: Block rdd_24_55 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:23 WARN BlockManager: Block rdd_24_57 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:24 WARN BlockManager: Block rdd_24_58 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:24 WARN BlockManager: Block rdd_24_59 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:24 WARN BlockManager: Block rdd_24_60 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:24 WARN BlockManager: Block rdd_24_61 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:24 WARN BlockManager: Block rdd_24_62 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:24 WARN BlockManager: Block rdd_24_64 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:24 WARN BlockManager: Block rdd_24_63 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:24 WARN BlockManager: Block rdd_24_65 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:26 WARN BlockManager: Block rdd_24_67 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:26 WARN BlockManager: Block rdd_24_68 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:26 WARN BlockManager: Block rdd_24_66 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:26 WARN BlockManager: Block rdd_24_69 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:26 WARN BlockManager: Block rdd_24_71 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:26 WARN BlockManager: Block rdd_24_70 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:26 WARN BlockManager: Block rdd_24_73 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:26 WARN BlockManager: Block rdd_24_72 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:27 WARN BlockManager: Block rdd_24_74 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:27 WARN BlockManager: Block rdd_24_75 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:27 WARN BlockManager: Block rdd_24_76 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:27 WARN BlockManager: Block rdd_24_78 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:27 WARN BlockManager: Block rdd_24_77 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:27 WARN BlockManager: Block rdd_24_79 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:27 WARN BlockManager: Block rdd_24_81 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:27 WARN BlockManager: Block rdd_24_80 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:28 WARN BlockManager: Block rdd_24_82 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:28 WARN BlockManager: Block rdd_24_83 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:28 WARN BlockManager: Block rdd_24_84 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:29 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:29 WARN BlockManager: Block rdd_24_87 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:29 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:29 WARN BlockManager: Block rdd_24_86 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:29 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:29 WARN BlockManager: Block rdd_24_85 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:30 WARN BlockManager: Block rdd_24_88 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:30 WARN BlockManager: Block rdd_24_89 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:30 WARN BlockManager: Block rdd_24_90 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:31 WARN BlockManager: Block rdd_24_91 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:31 WARN BlockManager: Block rdd_24_92 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:31 WARN BlockManager: Block rdd_24_93 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:32 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:32 WARN BlockManager: Block rdd_24_94 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:32 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:32 WARN BlockManager: Block rdd_24_95 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:32 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:32 WARN BlockManager: Block rdd_24_96 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:33 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:33 WARN BlockManager: Block rdd_24_97 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:34 WARN BlockManager: Block rdd_24_98 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:34 WARN BlockManager: Block rdd_24_99 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:34 WARN BlockManager: Block rdd_24_100 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:34 WARN BlockManager: Block rdd_24_101 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:34 WARN BlockManager: Block rdd_24_102 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:34 WARN BlockManager: Block rdd_24_103 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:35 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:35 WARN BlockManager: Block rdd_24_104 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:36 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:36 WARN BlockManager: Block rdd_24_105 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:37 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:37 WARN BlockManager: Block rdd_24_107 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:38 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:38 WARN BlockManager: Block rdd_24_109 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:38 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:38 WARN BlockManager: Block rdd_24_108 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:38 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:38 WARN BlockManager: Block rdd_24_106 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:38 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:38 WARN BlockManager: Block rdd_24_110 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:38 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:38 WARN BlockManager: Block rdd_24_111 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:39 WARN BlockManager: Block rdd_24_112 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:39 WARN BlockManager: Block rdd_24_113 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:41 WARN BlockManager: Block rdd_24_116 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:41 WARN BlockManager: Block rdd_24_114 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:41 WARN BlockManager: Block rdd_24_115 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:41 WARN BlockManager: Block rdd_24_117 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:41 WARN BlockManager: Block rdd_24_119 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:41 WARN BlockManager: Block rdd_24_118 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:42 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:42 WARN BlockManager: Block rdd_24_120 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:42 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:42 WARN BlockManager: Block rdd_24_121 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:44 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:44 WARN BlockManager: Block rdd_24_123 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:44 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:44 WARN BlockManager: Block rdd_24_122 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:44 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:44 WARN BlockManager: Block rdd_24_125 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:44 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:44 WARN BlockManager: Block rdd_24_124 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:44 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:44 WARN BlockManager: Block rdd_24_129 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:44 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:44 WARN BlockManager: Block rdd_24_128 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:44 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:44 WARN BlockManager: Block rdd_24_126 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:44 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:44 WARN BlockManager: Block rdd_24_127 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:47 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:47 WARN BlockManager: Block rdd_24_130 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:47 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:47 WARN BlockManager: Block rdd_24_137 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:47 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:47 WARN BlockManager: Block rdd_24_132 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:47 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:47 WARN BlockManager: Block rdd_24_131 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:47 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:47 WARN BlockManager: Block rdd_24_135 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:47 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:47 WARN BlockManager: Block rdd_24_133 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:48 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:48 WARN BlockManager: Block rdd_24_134 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:48 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:48 WARN BlockManager: Block rdd_24_136 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:51 WARN BlockManager: Block rdd_24_139 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:51 WARN BlockManager: Block rdd_24_138 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:51 WARN BlockManager: Block rdd_24_141 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:51 WARN BlockManager: Block rdd_24_140 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:51 WARN BlockManager: Block rdd_24_142 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:51 WARN BlockManager: Block rdd_24_145 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:51 WARN BlockManager: Block rdd_24_144 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:52 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:52 WARN BlockManager: Block rdd_24_143 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:54 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:54 WARN BlockManager: Block rdd_24_146 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:54 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:54 WARN BlockManager: Block rdd_24_147 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:55 WARN BlockManager: Block rdd_24_150 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:55 WARN BlockManager: Block rdd_24_148 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:55 WARN BlockManager: Block rdd_24_149 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:55 WARN BlockManager: Block rdd_24_151 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:55 WARN BlockManager: Block rdd_24_152 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:55 WARN BlockManager: Block rdd_24_153 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:58 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:58 WARN BlockManager: Block rdd_24_157 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:58 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:58 WARN BlockManager: Block rdd_24_155 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:59 WARN BlockManager: Block rdd_24_154 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:59 WARN BlockManager: Block rdd_24_156 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:59 WARN BlockManager: Block rdd_24_158 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:59 WARN BlockManager: Block rdd_24_160 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:14:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:14:59 WARN BlockManager: Block rdd_24_159 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:00 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:00 WARN BlockManager: Block rdd_24_161 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:05 WARN BlockManager: Block rdd_24_164 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:05 WARN BlockManager: Block rdd_24_163 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:05 WARN BlockManager: Block rdd_24_166 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:05 WARN BlockManager: Block rdd_24_162 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:05 WARN BlockManager: Block rdd_24_167 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:05 WARN BlockManager: Block rdd_24_165 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:05 WARN BlockManager: Block rdd_24_168 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:06 WARN BlockManager: Block rdd_24_169 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:13 WARN BlockManager: Block rdd_24_170 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:13 WARN BlockManager: Block rdd_24_174 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:13 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:13 WARN BlockManager: Block rdd_24_171 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:14 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:14 WARN BlockManager: Block rdd_24_175 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:14 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:14 WARN BlockManager: Block rdd_24_176 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:16 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:16 WARN BlockManager: Block rdd_24_177 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:16 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:16 WARN BlockManager: Block rdd_24_173 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:17 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:17 WARN BlockManager: Block rdd_24_172 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:22 WARN BlockManager: Block rdd_24_182 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:22 WARN BlockManager: Block rdd_24_180 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:22 WARN BlockManager: Block rdd_24_179 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:22 WARN BlockManager: Block rdd_24_183 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:22 WARN BlockManager: Block rdd_24_184 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:22 WARN BlockManager: Block rdd_24_181 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:22 WARN BlockManager: Block rdd_24_185 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:22 WARN BlockManager: Block rdd_24_178 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:26 WARN BlockManager: Block rdd_24_186 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:27 WARN BlockManager: Block rdd_24_189 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:27 WARN BlockManager: Block rdd_24_188 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:27 WARN BlockManager: Block rdd_24_190 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:27 WARN BlockManager: Block rdd_24_187 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:27 WARN BlockManager: Block rdd_24_192 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:27 WARN BlockManager: Block rdd_24_191 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:27 WARN BlockManager: Block rdd_24_193 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:31 WARN BlockManager: Block rdd_24_194 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:31 WARN BlockManager: Block rdd_24_196 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:31 WARN BlockManager: Block rdd_24_197 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:31 WARN BlockManager: Block rdd_24_195 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:31 WARN BlockManager: Block rdd_24_198 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 10:15:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 10:15:31 WARN BlockManager: Block rdd_24_199 replicated to only 0 peer(s) instead of 1 peers

# %%
data_train.count()
# Out:
# 806056

# %%
data_train.where(col(COL_USER)=='9640864').select(col(COL_TIMESTAMP)).show(10)
# Out:
# +-----------+
# |review_date|
# +-----------+
# | 2014-11-13|
# | 2015-02-14|
# +-----------+

# %%
data_test.where(col(COL_USER)=='9640864').select(col(COL_TIMESTAMP)).show(10)
# Out:
# +-----------+
# |review_date|
# +-----------+
# | 2015-03-04|
# +-----------+

# %% [markdown]
# ### 3.3.2 Min-rating filter
# A min-rating filter is applied to data before it is split by using chronological splitter. The reason of doing this is that, for multi-split, there should be sufficient number of ratings for user/item in the data.
#
# For example, the following means splitting only applies to users that have at least 10 ratings.

# %%
data_train, data_test = spark_chrono_split(
    data, filter_by="user", min_rating=2, ratio=0.7,
    col_user=COL_USER, col_item=COL_ITEM, col_timestamp=COL_TIMESTAMP
)
# Out:
# 22/05/15 11:27:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:51 WARN BlockManager: Block rdd_90_3 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:51 WARN BlockManager: Block rdd_90_5 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:51 WARN BlockManager: Block rdd_90_7 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:51 WARN BlockManager: Block rdd_90_2 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:51 WARN BlockManager: Block rdd_90_0 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:51 WARN BlockManager: Block rdd_90_1 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:51 WARN BlockManager: Block rdd_90_4 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:51 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:51 WARN BlockManager: Block rdd_90_6 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:52 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:52 WARN BlockManager: Block rdd_90_8 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:52 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:52 WARN BlockManager: Block rdd_90_15 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:52 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:52 WARN BlockManager: Block rdd_90_9 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:52 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:52 WARN BlockManager: Block rdd_90_13 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:52 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:52 WARN BlockManager: Block rdd_90_14 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:52 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:52 WARN BlockManager: Block rdd_90_10 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:52 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:52 WARN BlockManager: Block rdd_90_11 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:52 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:52 WARN BlockManager: Block rdd_90_12 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:53 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:53 WARN BlockManager: Block rdd_90_17 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:53 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:53 WARN BlockManager: Block rdd_90_23 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:53 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:53 WARN BlockManager: Block rdd_90_18 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:53 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:53 WARN BlockManager: Block rdd_90_16 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:53 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:53 WARN BlockManager: Block rdd_90_19 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:54 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:54 WARN BlockManager: Block rdd_90_21 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:54 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:54 WARN BlockManager: Block rdd_90_22 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:54 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:54 WARN BlockManager: Block rdd_90_20 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:55 WARN BlockManager: Block rdd_90_26 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:55 WARN BlockManager: Block rdd_90_24 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:55 WARN BlockManager: Block rdd_90_27 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:55 WARN BlockManager: Block rdd_90_28 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:55 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:55 WARN BlockManager: Block rdd_90_25 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:56 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:56 WARN BlockManager: Block rdd_90_29 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:56 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:56 WARN BlockManager: Block rdd_90_31 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:56 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:56 WARN BlockManager: Block rdd_90_30 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:56 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:56 WARN BlockManager: Block rdd_90_32 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:56 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:56 WARN BlockManager: Block rdd_90_34 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:56 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:56 WARN BlockManager: Block rdd_90_33 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:57 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:57 WARN BlockManager: Block rdd_90_35 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:57 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:57 WARN BlockManager: Block rdd_90_36 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:57 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:57 WARN BlockManager: Block rdd_90_38 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:57 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:57 WARN BlockManager: Block rdd_90_37 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:57 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:57 WARN BlockManager: Block rdd_90_39 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:58 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:58 WARN BlockManager: Block rdd_90_40 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:58 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:58 WARN BlockManager: Block rdd_90_41 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:58 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:58 WARN BlockManager: Block rdd_90_42 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:58 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:58 WARN BlockManager: Block rdd_90_43 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:58 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:58 WARN BlockManager: Block rdd_90_44 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:58 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:58 WARN BlockManager: Block rdd_90_45 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:58 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:58 WARN BlockManager: Block rdd_90_46 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:59 WARN BlockManager: Block rdd_90_47 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:59 WARN BlockManager: Block rdd_90_49 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:59 WARN BlockManager: Block rdd_90_48 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:59 WARN BlockManager: Block rdd_90_52 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:59 WARN BlockManager: Block rdd_90_50 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:59 WARN BlockManager: Block rdd_90_51 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:59 WARN BlockManager: Block rdd_90_53 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:27:59 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:27:59 WARN BlockManager: Block rdd_90_54 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:00 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:00 WARN BlockManager: Block rdd_90_55 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:00 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:00 WARN BlockManager: Block rdd_90_56 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:00 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:00 WARN BlockManager: Block rdd_90_60 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:00 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:00 WARN BlockManager: Block rdd_90_57 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_58 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_59 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_61 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_62 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_63 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_64 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_65 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_66 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_69 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_67 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:01 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:01 WARN BlockManager: Block rdd_90_68 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:02 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:02 WARN BlockManager: Block rdd_90_70 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:02 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:02 WARN BlockManager: Block rdd_90_71 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:02 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:02 WARN BlockManager: Block rdd_90_74 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:02 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:02 WARN BlockManager: Block rdd_90_72 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:02 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:02 WARN BlockManager: Block rdd_90_73 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:02 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:02 WARN BlockManager: Block rdd_90_75 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:02 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:02 WARN BlockManager: Block rdd_90_76 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:02 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:02 WARN BlockManager: Block rdd_90_77 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:03 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:03 WARN BlockManager: Block rdd_90_79 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:03 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:03 WARN BlockManager: Block rdd_90_78 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:03 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:03 WARN BlockManager: Block rdd_90_82 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:03 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:03 WARN BlockManager: Block rdd_90_80 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:03 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:03 WARN BlockManager: Block rdd_90_81 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:03 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:03 WARN BlockManager: Block rdd_90_83 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:03 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:03 WARN BlockManager: Block rdd_90_84 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:03 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:03 WARN BlockManager: Block rdd_90_85 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:03 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:03 WARN BlockManager: Block rdd_90_86 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:03 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:03 WARN BlockManager: Block rdd_90_87 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_88 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_89 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_90 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_91 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_93 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_94 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_92 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_97 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_95 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_96 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_98 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_99 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_100 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_102 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_101 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:04 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:04 WARN BlockManager: Block rdd_90_103 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:05 WARN BlockManager: Block rdd_90_105 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:05 WARN BlockManager: Block rdd_90_104 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:05 WARN BlockManager: Block rdd_90_109 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:05 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:05 WARN BlockManager: Block rdd_90_106 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_107 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_110 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_108 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_111 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_112 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_113 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_114 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_118 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_115 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_116 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_117 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:06 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:06 WARN BlockManager: Block rdd_90_119 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:07 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:07 WARN BlockManager: Block rdd_90_121 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:07 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:07 WARN BlockManager: Block rdd_90_120 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:07 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:07 WARN BlockManager: Block rdd_90_123 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:07 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:07 WARN BlockManager: Block rdd_90_125 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:07 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:07 WARN BlockManager: Block rdd_90_122 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:07 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:07 WARN BlockManager: Block rdd_90_126 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:07 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:07 WARN BlockManager: Block rdd_90_124 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:07 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:07 WARN BlockManager: Block rdd_90_127 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:07 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:07 WARN BlockManager: Block rdd_90_129 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:07 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:07 WARN BlockManager: Block rdd_90_128 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_131 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_130 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_132 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_134 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_133 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_135 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_136 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_137 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_138 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_143 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_139 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_140 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_141 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_142 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:08 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:08 WARN BlockManager: Block rdd_90_144 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_145 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_146 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_152 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_148 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_147 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_150 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_149 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_151 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_153 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_154 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:09 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:09 WARN BlockManager: Block rdd_90_155 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_156 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_157 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_158 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_160 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_159 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_161 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_162 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_163 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_164 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_166 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_167 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_165 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_168 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_169 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:10 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:10 WARN BlockManager: Block rdd_90_170 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_171 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_172 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_174 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_173 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_175 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_176 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_177 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_178 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_179 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_180 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_181 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_182 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:11 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:11 WARN BlockManager: Block rdd_90_183 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_184 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_185 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_186 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_188 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_187 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_189 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_190 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_191 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_192 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_193 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_194 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_196 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_197 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_199 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_195 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:28:12 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:28:12 WARN BlockManager: Block rdd_90_198 replicated to only 0 peer(s) instead of 1 peers

# %%
data_train.count() + data_test.count(), data.count()
# Out:
# (1405764, 3093869)

# %% [markdown]
# ## 3.3 Stratified Split
#
# Chronogically splitting method takes in a dataset and splits it by either user or item. The split is stratified so that the same set of users or items will appear in both training and testing data sets.
#
# Similar to chronological splitter, filter_by and min_rating_filter also apply to the stratified splitter.
#
# The following example shows the split of the sample data with a ratio of 0.7, and for each user there should be at least 10 ratings.

# %% [markdown]
# Chronogically splitting method takes in a dataset and splits it by either user or item. The split is stratified so that the same set of users or items will appear in both training and testing data sets.
#
# Similar to chronological splitter, filter_by and min_rating_filter also apply to the stratified splitter.
#
# The following example shows the split of the sample data with a ratio of 0.7, and for each user there should be at least 10 ratings.

# %%
data_train, data_test = spark_stratified_split(
    data, filter_by="user", min_rating=5, ratio=0.7,
    col_user=COL_USER, col_item=COL_ITEM
)
# Out:
# 22/05/15 11:29:21 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:21 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:21 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:21 WARN BlockManager: Block rdd_134_2 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:21 WARN BlockManager: Block rdd_134_6 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:21 WARN BlockManager: Block rdd_134_7 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:21 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:21 WARN BlockManager: Block rdd_134_1 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:21 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:21 WARN BlockManager: Block rdd_134_3 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:22 WARN BlockManager: Block rdd_134_0 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:22 WARN BlockManager: Block rdd_134_5 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:22 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:22 WARN BlockManager: Block rdd_134_4 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_9 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_14 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_12 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_8 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_10 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_13 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_15 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_11 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_18 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_20 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_16 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_17 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:23 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:23 WARN BlockManager: Block rdd_134_19 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_21 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_22 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_23 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_24 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_26 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_27 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_25 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_28 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_29 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_31 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_30 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_34 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_35 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_36 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:24 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:24 WARN BlockManager: Block rdd_134_32 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_33 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_40 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_39 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_38 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_37 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_41 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_42 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_43 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_47 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_44 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_46 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_45 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_48 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_49 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_50 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:25 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:25 WARN BlockManager: Block rdd_134_51 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_52 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_53 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_54 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_55 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_56 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_57 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_58 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_62 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_60 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_61 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_65 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_64 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_59 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_63 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_66 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_67 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_68 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:26 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:26 WARN BlockManager: Block rdd_134_69 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_71 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_70 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_72 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_73 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_74 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_75 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_79 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_78 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_80 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_76 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:27 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:27 WARN BlockManager: Block rdd_134_77 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_81 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_82 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_83 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_85 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_87 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_88 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_84 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_86 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_89 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_90 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:28 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:28 WARN BlockManager: Block rdd_134_91 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:29 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:29 WARN BlockManager: Block rdd_134_94 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:29 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:29 WARN BlockManager: Block rdd_134_93 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:29 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:29 WARN BlockManager: Block rdd_134_95 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:29 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:29 WARN BlockManager: Block rdd_134_96 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:29 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:29 WARN BlockManager: Block rdd_134_92 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_98 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_97 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_101 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_100 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_103 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_99 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_102 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_104 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_106 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_108 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_111 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_107 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_105 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_109 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:30 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:30 WARN BlockManager: Block rdd_134_110 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:31 WARN BlockManager: Block rdd_134_112 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:31 WARN BlockManager: Block rdd_134_113 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:31 WARN BlockManager: Block rdd_134_117 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:31 WARN BlockManager: Block rdd_134_118 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:31 WARN BlockManager: Block rdd_134_114 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:31 WARN BlockManager: Block rdd_134_116 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:31 WARN BlockManager: Block rdd_134_115 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:31 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:31 WARN BlockManager: Block rdd_134_119 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:32 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:32 WARN BlockManager: Block rdd_134_120 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:33 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:33 WARN BlockManager: Block rdd_134_121 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:33 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:33 WARN BlockManager: Block rdd_134_125 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:33 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:33 WARN BlockManager: Block rdd_134_124 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:33 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:33 WARN BlockManager: Block rdd_134_123 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:33 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:33 WARN BlockManager: Block rdd_134_122 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:33 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:33 WARN BlockManager: Block rdd_134_126 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:33 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:33 WARN BlockManager: Block rdd_134_127 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:33 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:33 WARN BlockManager: Block rdd_134_128 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:34 WARN BlockManager: Block rdd_134_131 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:34 WARN BlockManager: Block rdd_134_132 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:34 WARN BlockManager: Block rdd_134_130 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:34 WARN BlockManager: Block rdd_134_129 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:34 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:34 WARN BlockManager: Block rdd_134_133 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:35 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:35 WARN BlockManager: Block rdd_134_134 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:35 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:35 WARN BlockManager: Block rdd_134_135 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:35 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:35 WARN BlockManager: Block rdd_134_137 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:35 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:35 WARN BlockManager: Block rdd_134_139 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:35 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:35 WARN BlockManager: Block rdd_134_138 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:35 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:35 WARN BlockManager: Block rdd_134_136 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:35 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:35 WARN BlockManager: Block rdd_134_140 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:35 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:35 WARN BlockManager: Block rdd_134_141 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:36 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:36 WARN BlockManager: Block rdd_134_142 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:36 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:36 WARN BlockManager: Block rdd_134_146 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:36 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:36 WARN BlockManager: Block rdd_134_143 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:36 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:36 WARN BlockManager: Block rdd_134_144 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:36 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:36 WARN BlockManager: Block rdd_134_145 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:36 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:36 WARN BlockManager: Block rdd_134_147 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:36 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:36 WARN BlockManager: Block rdd_134_148 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:36 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:36 WARN BlockManager: Block rdd_134_149 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:37 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:37 WARN BlockManager: Block rdd_134_150 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:37 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:37 WARN BlockManager: Block rdd_134_151 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:37 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:37 WARN BlockManager: Block rdd_134_152 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:37 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:37 WARN BlockManager: Block rdd_134_155 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:37 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:37 WARN BlockManager: Block rdd_134_154 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:37 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:37 WARN BlockManager: Block rdd_134_153 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:37 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:37 WARN BlockManager: Block rdd_134_156 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:37 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:37 WARN BlockManager: Block rdd_134_157 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:38 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:38 WARN BlockManager: Block rdd_134_159 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:38 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:38 WARN BlockManager: Block rdd_134_160 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:38 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:38 WARN BlockManager: Block rdd_134_158 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:38 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:38 WARN BlockManager: Block rdd_134_161 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:39 WARN BlockManager: Block rdd_134_162 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:39 WARN BlockManager: Block rdd_134_164 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:39 WARN BlockManager: Block rdd_134_163 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:39 WARN BlockManager: Block rdd_134_165 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:39 WARN BlockManager: Block rdd_134_166 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:39 WARN BlockManager: Block rdd_134_167 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:39 WARN BlockManager: Block rdd_134_168 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:39 WARN BlockManager: Block rdd_134_169 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:39 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:39 WARN BlockManager: Block rdd_134_170 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:40 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:40 WARN BlockManager: Block rdd_134_171 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:40 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:40 WARN BlockManager: Block rdd_134_173 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:40 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:40 WARN BlockManager: Block rdd_134_172 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:40 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:40 WARN BlockManager: Block rdd_134_174 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:40 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:40 WARN BlockManager: Block rdd_134_175 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:40 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:40 WARN BlockManager: Block rdd_134_176 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:40 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:40 WARN BlockManager: Block rdd_134_177 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:40 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:40 WARN BlockManager: Block rdd_134_179 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:40 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:40 WARN BlockManager: Block rdd_134_178 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:41 WARN BlockManager: Block rdd_134_180 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:41 WARN BlockManager: Block rdd_134_181 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:41 WARN BlockManager: Block rdd_134_183 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:41 WARN BlockManager: Block rdd_134_184 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:41 WARN BlockManager: Block rdd_134_185 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:41 WARN BlockManager: Block rdd_134_187 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:41 WARN BlockManager: Block rdd_134_186 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:41 WARN BlockManager: Block rdd_134_182 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:41 WARN BlockManager: Block rdd_134_188 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:41 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:41 WARN BlockManager: Block rdd_134_189 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:42 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:42 WARN BlockManager: Block rdd_134_191 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:42 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:42 WARN BlockManager: Block rdd_134_190 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:43 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:43 WARN BlockManager: Block rdd_134_194 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:43 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:43 WARN BlockManager: Block rdd_134_195 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:43 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:43 WARN BlockManager: Block rdd_134_192 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:43 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:43 WARN BlockManager: Block rdd_134_193 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:43 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:43 WARN BlockManager: Block rdd_134_196 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:43 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:43 WARN BlockManager: Block rdd_134_197 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:43 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:43 WARN BlockManager: Block rdd_134_198 replicated to only 0 peer(s) instead of 1 peers
# 22/05/15 11:29:44 WARN RandomBlockReplicationPolicy: Expecting 1 replicas with only 0 peer/s.
# 22/05/15 11:29:44 WARN BlockManager: Block rdd_134_199 replicated to only 0 peer(s) instead of 1 peers

# %%
data_train.count() + data_test.count(), data.count()
# Out:
# (411774, 3093869)

# %% [markdown]
# ## 3.4 Data Split at Scale
#
# Spark DataFrame is used for scalable splitting. This allows splitting operation performed on large dataset that is distributed across Spark cluster.
#
# For example, the below illustrates how to do a random split on the given Spark DataFrame. For simplicity reason, the same MovieLens data, which is in Pandas DataFrame, is transformed into Spark DataFrame and used for splitting.

# %%
spark = start_or_get_spark()
data_spark = spark.read.csv(DATA_PATH)
data_spark_train, data_spark_test = spark_random_split(data_spark, ratio=0.7)
data_spark_train.count(), data_spark_test.count()
spark.stop()
# Out:
# ERROR:root:KeyboardInterrupt while sending command.                (0 + 8) / 13]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/lib/python3.9/site-packages/py4j/clientserver.py", line 475, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/usr/local/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6w/c2j2dv710qd_5zmdvfyykb6c0000gn/T/ipykernel_4055/3615335688.py in <module>
#       2 data_spark = spark.read.csv(DATA_PATH)
#       3 data_spark_train, data_spark_test = spark_random_split(data_spark, ratio=0.7)
# ----> 4 data_spark_train.count(), data_spark_test.count()
#       5 spark.stop()
#
# /usr/local/lib/python3.9/site-packages/pyspark/sql/dataframe.py in count(self)
#     678         2
#     679         """
# --> 680         return int(self._jdf.count())
#     681
#     682     def collect(self):
#
# /usr/local/lib/python3.9/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1318             proto.END_COMMAND_PART
#    1319
# -> 1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
#    1322             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/local/lib/python3.9/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#    1036         connection = self._get_connection()
#    1037         try:
# -> 1038             response = connection.send_command(command)
#    1039             if binary:
#    1040                 return response, self._create_connection_guard(connection)
#
# /usr/local/lib/python3.9/site-packages/py4j/clientserver.py in send_command(self, command)
#     473         try:
#     474             while True:
# --> 475                 answer = smart_decode(self.stream.readline()[:-1])
#     476                 logger.debug("Answer received: {0}".format(answer))
#     477                 # Happens when a the other end is dead. There might be an empty
#
# /usr/local/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# References
# Dimitris Paraschakis et al, "Comparative Evaluation of Top-N Recommenders in e-Commerce: An Industrial Perspective", IEEE ICMLA, 2015, Miami, FL, USA.
# Guy Shani and Asela Gunawardana, "Evaluating Recommendation Systems", Recommender Systems Handbook, Springer, 2015.
# Apache Spark, url: https://spark.apache.org/.
